# %% [markdown]
# ## This script shows the visualization of electricity, water and gas consumption using carpet plots
#
# #### Imports and paths

# %%
import os, sys
import time
import pytz
import inspect
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

script_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
# add the path to opengrid to sys.path
sys.path.append(os.path.join(script_dir, os.pardir, os.pardir))
from opengrid.library import config, houseprint, fluksoapi, plotting
c=config.Config()

# find tmpo
sys.path.append(c.get('tmpo', 'folder'))
import tmpo

# %matplotlib inline
plt.rcParams['figure.figsize'] = 16,8

# path to data
path_to_data = c.get('data', 'folder')
if not os.path.exists(path_to_data):
    raise IOError("Provide your path to the data in your config.ini file.  This is a folder containing a 'zip' and 'csv' subfolder.")
else:
    path_to_csv = os.path.join(path_to_data, 'csv')

# %% [markdown]
# ### Script settings

# %%
hp = houseprint.load_houseprint_from_file('hp_anonymous.pkl')
start = pd.Timestamp(time.time() - 30*86400, unit='s')
print "start: {}".format(start)
# Out:
# start: 2014-10-28 23:12:04.196000

# %% [markdown]
# ### Load the sensor data

# %%
dataframes = []
sensors = hp.get_all_sensors()
water_sensors = hp.get_sensors_by_type('water')
gas_sensors = hp.get_sensors_by_type('gas')
for sensor in sensors:
    dataframes.append(fluksoapi.load_csv(fluksoapi.find_csv(path_to_csv, sensor)))
 
print('{} Sensors loaded'.format(len(dataframes)))
 
df = dataframes[0].join(dataframes[1:], how='outer')
df.index = df.index.tz_convert(pytz.timezone('Europe/Brussels'))
print "Size of dataframe before slicing: {}".format(df.shape)
df = df.ix[start:]
print "Size of dataframe after slicing: {}".format(df.shape)
# Out:
# 68 Sensors loaded
# Size of dataframe before slicing: (355133, 68)
# Size of dataframe after slicing: (38928, 68)

# %% [markdown]
# ## Plots
#
# ### Electricity sensors

# %%
for sensor in hp.get_sensors_by_type('electricity'):
    if df[sensor].notnull().any():
        flukso_id=hp.get_flukso_from_sensor(sensor)
        plotting.carpet(df[sensor], title=flukso_id, zlabel=r'Power [W]')
        plt.savefig(os.path.join(path_to_data, 'figures', 'carpet_elec_'+flukso_id+'_'+sensor), dpi=100)
# Out:
# C:\Python27\lib\site-packages\matplotlib\pyplot.py:412: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# ### Water sensors

# %%
for sensor in hp.get_sensors_by_type('water'):
    if df[sensor].notnull().any():
        flukso_id=hp.get_flukso_from_sensor(sensor)
        plotting.carpet(df[sensor], title=flukso_id, zlabel=r'Flow [l/h] ?')
        plt.savefig(os.path.join(path_to_data, 'figures', 'carpet_water_'+flukso_id+'_'+sensor), dpi=100)

# %% [markdown]
# ### Gas sensors

# %%
for sensor in hp.get_sensors_by_type('gas'):
    if df[sensor].notnull().any():
        flukso_id=hp.get_flukso_from_sensor(sensor)
        plotting.carpet(df[sensor], title=flukso_id, zlabel=r'Flow [l/h] ?')
        plt.savefig(os.path.join(path_to_data, 'figures', 'carpet_gas_'+flukso_id+'_'+sensor), dpi=100)
