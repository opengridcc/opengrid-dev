# %% [markdown]
# ##Color fest

# %%
run 'cache_anonymous_houseprint.py'
# Out:
# Opengrid houseprint (Responses) successfully opened.
# Sensor data fetched
# Housprint object is anonymous
# Saved anonymous houseprint to G:\_L_scripts\OpengridCC\opengrid\scripts\hp_anonymous.pkl

# %%
colorfest = []
R_values = []
G_values = []
B_values = []
for line in open('tk_color_names_RGB_list.ssv','r'):
    p1, sep,leftover  = line.partition(' ')
    
    
    print(leftover)
    try:
        [p2,R,G,B]= leftover.split()
        colorfest.append(' '.join([a,p2]))
        R_values.append(R)
        G_values.append(G)
        B_values.append(B)
    except:   
        [R, G,B]= leftover.split()
        R_values.append(R)
        G_values.append(G)
        B_values.append(B)
print colorfest[5], R[5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-0efd66b3e7f9> in <module>()
#      15         B_values.append(B)
#      16     except:
# ---> 17         [R, G,B]= leftover.split()
#      18         R_values.append(R)
#      19         G_values.append(G)
#
# ValueError: too many values to unpack
# blue                 240   248   248
#
#                  240   248   248
#
# white              250   235   235
#
#               250   235   235
#
#              255   239   239
#
#              238   223   223
#
#              205   192   192
#
#              139   131   131
#
#                 127   255   255
#
#                127   255   255
#
#                118   238   238
#
#                102   205   205
#
#                 69   139   139
#
#                      240   255   255
#
#                     240   255   255
#
# ...
