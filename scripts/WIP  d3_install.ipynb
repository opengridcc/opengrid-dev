# %%
# !pip install bokeh
"""to install once 

"""
# Out:
# ...
# Downloading/unpacking greenlet>=0.4.1 (from bokeh)
#   Running setup.py egg_info for package greenlet
#
# ...
# Downloading/unpacking pytz==2013b (from bokeh)
#   Running setup.py egg_info for package pytz
#
# ...
# Downloading/unpacking six>=1.5.2 (from bokeh)
# ...
#   Running setup.py egg_info for package six
#
#     no previously-included directories found matching 'documentation\_build'
# ...
# Downloading/unpacking pystache>=0.5.3 (from bokeh)
#   Running setup.py egg_info for package pystache
#     pystache: using: version '2.0.2' of <module 'setuptools' from 'C:\winpython\WinPython-32bit-2.7.6.2\python-2.7.6\lib\site-packages\setuptools\__init__.pyc'>
#
# Downloading/unpacking markdown>=2.3.1 (from bokeh)
#   Running setup.py egg_info for package markdown
#
# Downloading/unpacking PyYAML>=3.10 (from bokeh)
#   Running setup.py egg_info for package PyYAML
#
#     skipping 'ext\_yaml.c' Cython extension (up-to-date)
# Downloading/unpacking pyzmq>=14.3.1 (from bokeh)
# ...

# %%
# !pip install Flask
# !pip install Requests
# !pip install gevent
# !pip install gevent-websocket
print('dependencies ok')

"""    NumPy
    Flask
    Redis
    Requests
    gevent
    gevent-websocket
    Pandas
"""
# Out:
# ...
# Cleaning up...
# ...
# Cleaning up...
# Downloading/unpacking gevent
#   Running setup.py egg_info for package gevent
#
# Downloading/unpacking greenlet (from gevent)
#   Running setup.py egg_info for package greenlet
#
# ...
#   Running setup.py install for gevent
#     building 'gevent.core' extension
#     error: Unable to find vcvarsall.bat
#     Complete output from command C:\winpython\WinPython-32bit-2.7.6.2\python-2.7.6\python.exe -c "import setuptools;__file__='c:\\users\\u0068667\\appdata\\local\\temp\\pip_build_u0068667\\gevent\\setup.py';exec(compile(open(__file__).read().replace('\r\n', '\n'), __file__, 'exec'))" install --record c:\users\u0068667\appdata\local\temp\pip-_4h_h_-record\install-record.txt --single-version-externally-managed:
#     running install
#
# running build
#
# running build_py
#
# creating build
#
# creating build\lib.win32-2.7
#
# creating build\lib.win32-2.7\gevent
#
# copying gevent\backdoor.py -> build\lib.win32-2.7\gevent
#
# ...

# %%
bokeh-server --backend=redis
# Out:
#   File "<ipython-input-10-569381fccbeb>", line 1
#     bokeh-server --backend=redis
# SyntaxError: can't assign to operator
